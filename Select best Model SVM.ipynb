# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv('user_behavior_dataset_preprocessed.csv')

# %%
data
# Out:
#      Device Model  Operating System  App Usage Time (min/day)  \
# 0               0                 0                       393
# 1               1                 0                       268
# 2               2                 0                       154
# 3               0                 0                       239
# 4               3                 1                       187
# ..            ...               ...                       ...
# 695             3                 1                        92
# 696             2                 0                       316
# 697             0                 0                        99
# 698             4                 0                        62
# 699             1                 0                       212
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                           6.4                     1872
# 1                           4.7                     1331
# 2                           4.0                      761
# 3                           4.8                     1676
# 4                           4.3                     1367
# ..                          ...                      ...
# 695                         3.9                     1082
# 696                         6.8                     1965
# 697                         3.1                      942
# 698                         1.7                      431
# 699                         5.4                     1306
#
#      Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                          67                 1122   40       1
# 1                          42                  944   47       0
# 2                          32                  322   42       1
# 3                          56                  871   20       1
# 4                          58                  988   31       0
# ..                        ...                  ...  ...     ...
# 695                        26                  381   22       1
# 696                        68                 1201   59       1
# 697                        22                  457   50       0
# 698                        13                  224   44       1
# 699                        49                  828   23       0
#
#      User Behavior Class
# 0                      4
# 1                      3
# 2                      2
# 3                      3
# 4                      3
# ..                   ...
# 695                    2
# 696                    4
# 697                    2
# 698                    1
# 699                    3
#
# [700 rows x 10 columns]

# %%
data.isnull().sum()
# Out:
# Device Model                  0
# Operating System              0
# App Usage Time (min/day)      0
# Screen On Time (hours/day)    0
# Battery Drain (mAh/day)       0
# Number of Apps Installed      0
# Data Usage (MB/day)           0
# Age                           0
# Gender                        0
# User Behavior Class           0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Device Model                700 non-null    int64
#  1   Operating System            700 non-null    int64
#  2   App Usage Time (min/day)    700 non-null    int64
#  3   Screen On Time (hours/day)  700 non-null    float64
#  4   Battery Drain (mAh/day)     700 non-null    int64
#  5   Number of Apps Installed    700 non-null    int64
#  6   Data Usage (MB/day)         700 non-null    int64
#  7   Age                         700 non-null    int64
#  8   Gender                      700 non-null    int64
#  9   User Behavior Class         700 non-null    int64
# dtypes: float64(1), int64(9)
# memory usage: 54.8 KB

# %%
data.columns
# Out:
# Index(['Device Model', 'Operating System', 'App Usage Time (min/day)',
#        'Screen On Time (hours/day)', 'Battery Drain (mAh/day)',
#        'Number of Apps Installed', 'Data Usage (MB/day)', 'Age', 'Gender',
#        'User Behavior Class'],
#       dtype='object')

# %%
# seleced column: Index(['App Usage Time (min/day)', 'Screen On Time (hours/day)',
#        'Battery Drain (mAh/day)', 'Number of Apps Installed',
#        'Data Usage (MB/day)'],

X_indep=data[['App Usage Time (min/day)','Screen On Time (hours/day)','Battery Drain (mAh/day)', 'Number of Apps Installed','Data Usage (MB/day)']]

# %%
X_indep.columns
# Out:
# Index(['App Usage Time (min/day)', 'Screen On Time (hours/day)',
#        'Battery Drain (mAh/day)', 'Number of Apps Installed',
#        'Data Usage (MB/day)'],
#       dtype='object')

# %%
Y_dep=data['User Behavior Class']

# %%
Y_dep
# Out:
# 0      4
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 695    2
# 696    4
# 697    2
# 698    1
# 699    3
# Name: User Behavior Class, Length: 700, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        36
#            2       1.00      1.00      1.00        38
#            3       1.00      1.00      1.00        56
#            4       1.00      1.00      1.00        38
#            5       1.00      1.00      1.00        42
#
#     accuracy                           1.00       210
#    macro avg       1.00      1.00      1.00       210
# weighted avg       1.00      1.00      1.00       210

# %%
Y_test
# Out:
# 306    3
# 604    3
# 40     3
# 493    4
# 14     3
#       ..
# 540    5
# 623    1
# 15     5
# 420    1
# 247    4
# Name: User Behavior Class, Length: 210, dtype: int64

# %%
grid.predict_proba(X_test)[:,-1]
# Out:
# array([0.00326905, 0.00330511, 0.00238601, 0.00505562, 0.00749625,
#        0.01883209, 0.99596597, 0.01061221, 0.9424584 , 0.01620778,
#        0.00287096, 0.00197823, 0.00613422, 0.00137505, 0.01459047,
#        0.00317107, 0.00504909, 0.00305862, 0.00529459, 0.99765253,
#        0.00186867, 0.00269706, 0.00190062, 0.00215692, 0.00413933,
#        0.99564324, 0.12531267, 0.00312021, 0.00328561, 0.00323807,
#        0.01562007, 0.00230391, 0.00359496, 0.00324639, 0.00681184,
#        0.0012706 , 0.00291221, 0.0043121 , 0.99655153, 0.00458381,
#        0.00290031, 0.73123728, 0.0662463 , 0.00135568, 0.98277639,
#        0.00764139, 0.95254292, 0.01849418, 0.00806617, 0.00992327,
#        0.00299478, 0.00175318, 0.93176132, 0.00325488, 0.00418054,
#        0.00488344, 0.9886529 , 0.0022476 , 0.00668274, 0.00311654,
#        0.00647798, 0.00347598, 0.00337351, 0.00207632, 0.0748006 ,
#        0.00217501, 0.0031561 , 0.00299194, 0.00229079, 0.00371028,
#        0.00353846, 0.00217879, 0.9393956 , 0.00241406, 0.97759145,
#        0.99464351, 0.0038031 , 0.00256521, 0.00500304, 0.00158316,
#        0.00294051, 0.00217262, 0.0040639 , 0.00656256, 0.00497274,
#        0.00953243, 0.99556191, 0.00446769, 0.22318551, 0.00306575,
#        0.00698099, 0.96849543, 0.00130454, 0.00344496, 0.99759183,
#        0.08094915, 0.99521128, 0.99470018, 0.0046155 , 0.00162153,
#        0.05272325, 0.00870568, 0.00273948, 0.00336453, 0.00127908,
#        0.00298255, 0.00214616, 0.93968015, 0.97996338, 0.00262479,
#        0.00279245, 0.00199431, 0.00122909, 0.00214727, 0.04531164,
#        0.00233011, 0.00391819, 0.00174252, 0.00332049, 0.00310723,
#        0.00164853, 0.00260496, 0.97116462, 0.00325426, 0.00376265,
#        0.00660129, 0.00208832, 0.99309034, 0.00488487, 0.00389959,
#        0.99231005, 0.00586493, 0.00306619, 0.00201644, 0.91252429,
#        0.00335975, 0.00362254, 0.00468074, 0.99842778, 0.9974861 ,
#        0.97315202, 0.90647258, 0.00241423, 0.0024737 , 0.0028339 ,
#        0.00164475, 0.00229194, 0.00289011, 0.00331784, 0.00228105,
#        0.00228244, 0.98153995, 0.93866362, 0.00276466, 0.98354475,
#        0.00303767, 0.00637998, 0.00313016, 0.00117825, 0.00310493,
#        0.01315348, 0.00220187, 0.0016487 , 0.00584969, 0.00326632,
#        0.00423317, 0.97952294, 0.00527411, 0.87450053, 0.0037214 ,
#        0.12339702, 0.00276824, 0.00283123, 0.00506657, 0.0055217 ,
#        0.95745485, 0.00322875, 0.8947343 , 0.00898177, 0.99787227,
#        0.99488372, 0.00259597, 0.01473449, 0.99643643, 0.00129198,
#        0.99549234, 0.00632681, 0.00498201, 0.00251328, 0.00241907,
#        0.00682461, 0.00451992, 0.01479611, 0.0014952 , 0.03779687,
#        0.00163384, 0.00308604, 0.00573072, 0.01140746, 0.00820418,
#        0.99667059, 0.00286915, 0.00260645, 0.00304509, 0.00210822,
#        0.99687914, 0.0025567 , 0.98674158, 0.00218099, 0.00691012])

# %%
roc_auc_score(Y_test,grid.predict_proba(X_test), multi_class='ovr')
# Out:
# 1.0

# %%
import pickle

# %%
filename='Mobile_usage_SVM_besk_model.sav'

# %%
# pickle.dump(grid,open(filename,'wb'))

# %%
load_modle=pickle.load(open('Mobile_usage_SVM_besk_model.sav','rb'))

# %%
load_modle.feature_names_in_
# Out:
# array(['App Usage Time (min/day)', 'Screen On Time (hours/day)',
#        'Battery Drain (mAh/day)', 'Number of Apps Installed',
#        'Data Usage (MB/day)'], dtype=object)

# %%
get_inputvalue = []

for i in load_modle.feature_names_in_:
    
    if i=='App Usage Time (min/day)':
        print(f"Enter Device Model for {i}:")
        print("Options:0-max (numeric value)")
        model = int(input("Enter the corresponding number: "))
        get_inputvalue.append(model)
    if i=='Screen On Time (hours/day)':
        print(f"Enter Device Model for {i}:")
        print("Options:0-max (numeric value)")
        model = int(input("Enter the corresponding number: "))
        get_inputvalue.append(model)
    if i=='Battery Drain (mAh/day)':
        print(f"Enter Device Model for {i}:")
        print("Options:0-max (numeric value)")
        model = int(input("Enter the corresponding number: "))
        get_inputvalue.append(model)
    if i=='Number of Apps Installed':
        print(f"Enter Device Model for {i}:")
        print("Options:0-max (numeric value)")
        model = int(input("Enter the corresponding number: "))
        get_inputvalue.append(model)
    if i=='Data Usage (MB/day)':
        print(f"Enter Device Model for {i}:")
        print("Options:0-max (numeric value)")
        model = int(input("Enter the corresponding number: "))
        get_inputvalue.append(model)
    
print(get_inputvalue)
# Out:
# Enter Device Model for App Usage Time (min/day):
# Options:0-max (numeric value)
# Enter the corresponding number:  2345
# Enter Device Model for Screen On Time (hours/day):
# Options:0-max (numeric value)
# Enter the corresponding number:  2313
# Enter Device Model for Battery Drain (mAh/day):
# Options:0-max (numeric value)
# Enter the corresponding number:  22332
# Enter Device Model for Number of Apps Installed:
# Options:0-max (numeric value)
# Enter the corresponding number:  23
# Enter Device Model for Data Usage (MB/day):
# Options:0-max (numeric value)
# Enter the corresponding number:  2345
# [2345, 2313, 22332, 23, 2345]

# %%
newpredict=load_modle.predict([get_inputvalue])
# Out:
# C:\Users\mojayara\myenv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
newpredict[0]
# Out:
# np.int64(5)

# %%
label_mapping = {
    1: "1-Light Usage",
    2: "2-Moderate Usage",
    3: "3-Regular Usage",
    4: "4-High Usage",
    5: "5-Extreme Usage"
}

# %%
label_mapping[newpredict[0]]
# Out:
# '5-Extreme Usage'
