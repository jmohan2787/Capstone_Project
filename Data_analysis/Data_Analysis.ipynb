# %%
import pandas as pd

# %%
data=pd.read_csv('user_behavior_dataset_preprocessed.csv')

# %%
data
# Out:
#      Device Model  Operating System  App Usage Time (min/day)  \
# 0               0                 0                       393
# 1               1                 0                       268
# 2               2                 0                       154
# 3               0                 0                       239
# 4               3                 1                       187
# ..            ...               ...                       ...
# 695             3                 1                        92
# 696             2                 0                       316
# 697             0                 0                        99
# 698             4                 0                        62
# 699             1                 0                       212
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                           6.4                     1872
# 1                           4.7                     1331
# ...

# %%
data.isnull().sum()
# Out:
# Device Model                  0
# Operating System              0
# App Usage Time (min/day)      0
# Screen On Time (hours/day)    0
# Battery Drain (mAh/day)       0
# Number of Apps Installed      0
# Data Usage (MB/day)           0
# Age                           0
# Gender                        0
# User Behavior Class           0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Device Model                700 non-null    int64
#  1   Operating System            700 non-null    int64
#  2   App Usage Time (min/day)    700 non-null    int64
#  3   Screen On Time (hours/day)  700 non-null    float64
#  4   Battery Drain (mAh/day)     700 non-null    int64
#  5   Number of Apps Installed    700 non-null    int64
#  6   Data Usage (MB/day)         700 non-null    int64
#  7   Age                         700 non-null    int64
#  8   Gender                      700 non-null    int64
#  9   User Behavior Class         700 non-null    int64
# dtypes: float64(1), int64(9)
# memory usage: 54.8 KB

# %%
import seaborn as  sns

# %%
data['User Behavior Class'].value_counts()
# Out:
# User Behavior Class
# 2    146
# 3    143
# 4    139
# 5    136
# 1    136
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
label_mapping = {1: "1-Light Usage",2: "2-Moderate Usage",3: "3-Regular Usage",4: "4-High Usage",5: "5-Extreme Usage"}
plt.pie(data['User Behavior Class'].value_counts(),labels=data['User Behavior Class'].value_counts().index.map(label_mapping),autopct='%1.1f%%')
plt.title('Distribution of User Behavior Classes')
# plt.tight_layout()
# plt.show()
# Out:
# Text(0.5, 1.0, 'Distribution of User Behavior Classes')

# %%
data.describe()
# Out:
#        Device Model  Operating System  App Usage Time (min/day)  \
# count    700.000000        700.000000                700.000000
# mean       1.992857          0.208571                271.128571
# std        1.404552          0.406578                177.199484
# min        0.000000          0.000000                 30.000000
# 25%        1.000000          0.000000                113.250000
# 50%        2.000000          0.000000                227.500000
# 75%        3.000000          0.000000                434.250000
# max        4.000000          1.000000                598.000000
#
#        Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# count                  700.000000               700.000000
# mean                     5.272714              1525.158571
# std                      3.068584               819.136414
# min                      1.000000               302.000000
# 25%                      2.500000               722.250000
# ...

# %%
data['Gender'].value_counts().index
plt.pie(data['Gender'].value_counts(),labels=data['Gender'].value_counts().index,autopct='%1.1f%%')
plt.title('Data Usage by Gender')
plt.show()

# %%
data['Device Model'].value_counts()
# Out:
# Device Model
# 2    146
# 3    146
# 0    142
# 1    133
# 4    133
# Name: count, dtype: int64

# %%
# sns.barplot(x=data['Device Model'].value_counts(),y=data['Device Model'].value_counts().index,hue='Device Model',data=data)
import seaborn as sns
sns.barplot(x=data['Device Model'], y=data['App Usage Time (min/day)'],hue='Gender',data=data)
plt.title('Average App Usage Time by Device Model')

plt.show()

# %%
data
# Out:
#      Device Model  Operating System  App Usage Time (min/day)  \
# 0               0                 0                       393
# 1               1                 0                       268
# 2               2                 0                       154
# 3               0                 0                       239
# 4               3                 1                       187
# ..            ...               ...                       ...
# 695             3                 1                        92
# 696             2                 0                       316
# 697             0                 0                        99
# 698             4                 0                        62
# 699             1                 0                       212
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                           6.4                     1872
# 1                           4.7                     1331
# ...

# %%
data.columns
# Out:
# Index(['Device Model', 'Operating System', 'App Usage Time (min/day)',
#        'Screen On Time (hours/day)', 'Battery Drain (mAh/day)',
#        'Number of Apps Installed', 'Data Usage (MB/day)', 'Age', 'Gender',
#        'User Behavior Class'],
#       dtype='object')

# %%
sns.barplot(x=data['Gender'], y=data['App Usage Time (min/day)'],hue='Gender',data=data)
plt.title('Average App Usage Time by Age Group')

plt.show()

# %%
sns.histplot(data=data,x='Device Model',kde=True, hue='Operating System')
plt.title('Histogram Device Model')
plt.show()

# %%
data['Device Model'].value_counts().item
# Out:
# <bound method IndexOpsMixin.item of Device Model
# 2    146
# 3    146
# 0    142
# 1    133
# 4    133
# Name: count, dtype: int64>

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['Device Model', 'Operating System', 'App Usage Time (min/day)',
#        'Screen On Time (hours/day)', 'Battery Drain (mAh/day)',
#        'Number of Apps Installed', 'Data Usage (MB/day)', 'Age', 'Gender',
#        'User Behavior Class'],
#       dtype='object')

# %%
plt.scatter(data['Number of Apps Installed'],data['Battery Drain (mAh/day)'])
plt.show()
